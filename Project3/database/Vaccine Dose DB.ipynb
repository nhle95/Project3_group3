# %%
# Module used to connect Python with MongoDB
import pymongo
import csv
import pandas as pd

# %%
data = pd.read_csv ('dose.csv')

# %%
data.head(5)
# Out:
#          Location Dose_1_Administered Dose_2_Administered  \
# 0         Alabama   3,157,415 (64.4%)   2,464,644 (50.3%)
# 1          Alaska     528,402 (72.2%)     440,702 (60.2%)
# 2  American Samoa      45,985 (97.0%)      42,177 (89.0%)
# 3         Arizona   5,542,126 (76.1%)   4,535,261 (62.3%)
# 4        Arkansas   2,082,860 (69.0%)   1,619,991 (53.7%)
#
#    Doses_Per_100_People
# 0                137.00
# 1                173.56
# 2                241.78
# 3                190.15
# 4                154.81

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client['vaccinedoseDB']
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'vaccinedoseDB')

# %%
data1 = data.to_dict(orient = 'records')
data1
# Out:
# [{'Location': 'Alabama',
#   'Dose_1_Administered': '3,157,415 (64.4%)',
#   'Dose_2_Administered': '2,464,644 (50.3%)',
#   'Doses_Per_100_People': 137.0},
#  {'Location': 'Alaska',
#   'Dose_1_Administered': '528,402 (72.2%)',
#   'Dose_2_Administered': '440,702 (60.2%)',
#   'Doses_Per_100_People': 173.56},
#  {'Location': 'American Samoa',
#   'Dose_1_Administered': '45,985 (97.0%)',
#   'Dose_2_Administered': '42,177 (89.0%)',
#   'Doses_Per_100_People': 241.78},
#  {'Location': 'Arizona',
#   'Dose_1_Administered': '5,542,126 (76.1%)',
#   'Dose_2_Administered': '4,535,261 (62.3%)',
#   'Doses_Per_100_People': 190.15},
#  {'Location': 'Arkansas',
#   'Dose_1_Administered': '2,082,860 (69.0%)',
#   'Dose_2_Administered': '1,619,991 (53.7%)',
#   'Doses_Per_100_People': 154.81},
#  {'Location': 'California',
#   'Dose_1_Administered': '33,683,407 (85.2%)',
#   'Dose_2_Administered': '28,288,738 (71.6%)',
#   'Doses_Per_100_People': 209.94},
#  {'Location': 'Colorado',
#   'Dose_1_Administered': '4,755,725 (82.6%)',
#   'Dose_2_Administered': '4,019,019 (69.8%)',
#   'Doses_Per_100_People': 213.19},
#  {'Location': 'Connecticut',
#   'Dose_1_Administered': '3,574,567 (100.0%)',
#   'Dose_2_Administered': '2,792,422 (78.3%)',
#   'Doses_Per_100_People': 240.53},
#  {'Location': 'Delaware',
#   'Dose_1_Administered': '842,461 (86.5%)',
#   'Dose_2_Administered': '667,972 (68.6%)',
#   'Doses_Per_100_People': 207.66},
#  {'Location': 'District of Columbia',
#   'Dose_1_Administered': '777,417 (100.0%)',
#   'Dose_2_Administered': '565,155 (80.1%)',
#   'Doses_Per_100_People': 260.56},
#  {'Location': 'Florida',
#   'Dose_1_Administered': '17,528,535 (81.6%)',
#   'Dose_2_Administered': '13,802,252 (64.3%)',
#   'Doses_Per_100_People': 189.43},
#  {'Location': 'Georgia',
#   'Dose_1_Administered': '7,167,617 (67.5%)',
#   'Dose_2_Administered': '5,796,758 (54.6%)',
#   'Doses_Per_100_People': 154.04},
#  {'Location': 'Guam',
#   'Dose_1_Administered': '157,402 (93.4%)',
#   'Dose_2_Administered': '135,161 (80.2%)',
#   'Doses_Per_100_People': 227.41},
#  {'Location': 'Hawaii',
#   'Dose_1_Administered': '1,280,229 (90.4%)',
#   'Dose_2_Administered': '1,108,377 (78.3%)',
#   'Doses_Per_100_People': 236.37},
#  {'Location': 'Idaho',
#   'Dose_1_Administered': '1,129,423 (63.2%)',
#   'Dose_2_Administered': '942,177 (52.7%)',
#   'Doses_Per_100_People': 153.46},
#  {'Location': 'Illinois',
#   'Dose_1_Administered': '9,938,834 (78.4%)',
#   'Dose_2_Administered': '8,618,844 (68.0%)',
#   'Doses_Per_100_People': 201.15},
#  {'Location': 'Indiana',
#   'Dose_1_Administered': '4,288,871 (63.7%)',
#   'Dose_2_Administered': '3,672,834 (54.6%)',
#   'Doses_Per_100_People': 158.09},
#  {'Location': 'Iowa',
#   'Dose_1_Administered': '2,206,878 (69.9%)',
#   'Dose_2_Administered': '1,913,708 (60.7%)',
#   'Doses_Per_100_People': 183.55},
#  {'Location': 'Kansas',
#   'Dose_1_Administered': '2,190,186 (75.2%)',
#   'Dose_2_Administered': '1,797,648 (61.7%)',
#   'Doses_Per_100_People': 175.13},
#  {'Location': 'Kentucky',
#   'Dose_1_Administered': '3,044,853 (68.2%)',
#   'Dose_2_Administered': '2,501,616 (56.0%)',
#   'Doses_Per_100_People': 161.09},
#  {'Location': 'Louisiana',
#   'Dose_1_Administered': '2,901,555 (62.4%)',
#   'Dose_2_Administered': '2,417,401 (52.0%)',
#   'Doses_Per_100_People': 144.94},
#  {'Location': 'Maine',
#   'Dose_1_Administered': '1,279,155 (95.2%)',
#   'Dose_2_Administered': '1,033,737 (76.9%)',
#   'Doses_Per_100_People': 245.41},
#  {'Location': 'Maryland',
#   'Dose_1_Administered': '5,459,941 (90.3%)',
#   'Dose_2_Administered': '4,602,282 (76.1%)',
#   'Doses_Per_100_People': 229.49},
#  {'Location': 'Massachusetts',
#   'Dose_1_Administered': '7,162,857 (100.0%)',
#   'Dose_2_Administered': '5,502,399 (79.8%)',
#   'Doses_Per_100_People': 246.02},
#  {'Location': 'Michigan',
#   'Dose_1_Administered': '6,874,724 (68.8%)',
#   'Dose_2_Administered': '5,942,741 (59.5%)',
#   'Doses_Per_100_People': 178.39},
#  {'Location': 'Minnesota',
#   'Dose_1_Administered': '4,388,677 (77.8%)',
#   'Dose_2_Administered': '3,891,826 (69.0%)',
#   'Doses_Per_100_People': 212.22},
#  {'Location': 'Mississippi',
#   'Dose_1_Administered': '1,822,277 (61.2%)',
#   'Dose_2_Administered': '1,527,918 (51.3%)',
#   'Doses_Per_100_People': 139.95},
#  {'Location': 'Missouri',
#   'Dose_1_Administered': '4,203,177 (68.5%)',
#   'Dose_2_Administered': '3,427,538 (55.8%)',
#   'Doses_Per_100_People': 162.75},
#  {'Location': 'Montana',
#   'Dose_1_Administered': '721,120 (67.5%)',
#   'Dose_2_Administered': '589,874 (55.2%)',
#   'Doses_Per_100_People': 166.41},
#  {'Location': 'Nebraska',
#   'Dose_1_Administered': '1,401,699 (72.5%)',
#   'Dose_2_Administered': '1,218,454 (63.0%)',
#   'Doses_Per_100_People': 184.55},
#  {'Location': 'Nevada',
#   'Dose_1_Administered': '2,399,499 (77.9%)',
#   'Dose_2_Administered': '1,813,109 (58.9%)',
#   'Doses_Per_100_People': 174.26},
#  {'Location': 'New Hampshire',
#   'Dose_1_Administered': '1,171,475 (86.2%)',
#   'Dose_2_Administered': '912,316 (67.1%)',
#   'Doses_Per_100_People': 201.5},
#  {'Location': 'New Jersey',
#   'Dose_1_Administered': '8,304,839 (93.5%)',
#   'Dose_2_Administered': '6,643,796 (74.8%)',
#   'Doses_Per_100_People': 213.59},
#  {'Location': 'New Mexico',
#   'Dose_1_Administered': '1,936,526 (92.4%)',
#   'Dose_2_Administered': '1,490,229 (71.1%)',
#   'Doses_Per_100_People': 213.15},
#  {'Location': 'New York State',
#   'Dose_1_Administered': '18,127,801 (93.2%)',
#   'Dose_2_Administered': '14,734,975 (75.7%)',
#   'Doses_Per_100_People': 221.78},
#  {'Location': 'North Carolina',
#   'Dose_1_Administered': '9,436,791 (90.0%)',
#   'Dose_2_Administered': '6,516,479 (62.1%)',
#   'Doses_Per_100_People': 177.88},
#  {'Location': 'North Dakota',
#   'Dose_1_Administered': '521,085 (68.4%)',
#   'Dose_2_Administered': '418,006 (54.9%)',
#   'Doses_Per_100_People': 162.81},
#  {'Location': 'Northern Mariana Islands',
#   'Dose_1_Administered': '46,252 (89.2%)',
#   'Dose_2_Administered': '43,090 (83.1%)',
#   'Doses_Per_100_People': 220.61},
#  {'Location': 'Ohio',
#   'Dose_1_Administered': '7,607,174 (65.1%)',
#   'Dose_2_Administered': '6,690,031 (57.2%)',
#   'Doses_Per_100_People': 171.02},
#  {'Location': 'Oklahoma',
#   'Dose_1_Administered': '2,916,711 (73.7%)',
#   'Dose_2_Administered': '2,255,482 (57.0%)',
#   'Doses_Per_100_People': 164.05},
#  {'Location': 'Oregon',
#   'Dose_1_Administered': '3,390,544 (80.4%)',
#   'Dose_2_Administered': '2,874,791 (68.2%)',
#   'Doses_Per_100_People': 207.93},
#  {'Location': 'Pennsylvania',
#   'Dose_1_Administered': '11,374,249 (88.8%)',
#   'Dose_2_Administered': '8,723,971 (68.1%)',
#   'Doses_Per_100_People': 202.48},
#  {'Location': 'Puerto Rico',
#   'Dose_1_Administered': '3,122,711 (97.8%)',
#   'Dose_2_Administered': '2,699,668 (84.5%)',
#   'Doses_Per_100_People': 245.4},
#  {'Location': 'Rhode Island',
#   'Dose_1_Administered': '1,106,274 (100.0%)',
#   'Dose_2_Administered': '888,584 (83.9%)',
#   'Doses_Per_100_People': 237.35},
#  {'Location': 'South Carolina',
#   'Dose_1_Administered': '3,611,981 (70.2%)',
#   'Dose_2_Administered': '2,913,541 (56.6%)',
#   'Doses_Per_100_People': 161.07},
#  {'Location': 'South Dakota',
#   'Dose_1_Administered': '725,232 (82.0%)',
#   'Dose_2_Administered': '549,703 (62.1%)',
#   'Doses_Per_100_People': 180.75},
#  {'Location': 'Tennessee',
#   'Dose_1_Administered': '4,365,370 (63.9%)',
#   'Dose_2_Administered': '3,668,823 (53.7%)',
#   'Doses_Per_100_People': 160.05},
#  {'Location': 'Texas',
#   'Dose_1_Administered': '21,779,643 (75.1%)',
#   'Dose_2_Administered': '17,225,286 (59.4%)',
#   'Doses_Per_100_People': 169.51},
#  {'Location': 'Utah',
#   'Dose_1_Administered': '2,388,357 (74.5%)',
#   'Dose_2_Administered': '2,023,342 (63.1%)',
#   'Doses_Per_100_People': 182.49},
#  {'Location': 'Vermont',
#   'Dose_1_Administered': '609,521 (97.7%)',
#   'Dose_2_Administered': '505,211 (81.0%)',
#   'Doses_Per_100_People': 262.69},
#  {'Location': 'Virgin Islands',
#   'Dose_1_Administered': '73,193 (68.9%)',
#   'Dose_2_Administered': '56,483 (53.1%)',
#   'Doses_Per_100_People': 142.98},
#  {'Location': 'Virginia',
#   'Dose_1_Administered': '7,616,979 (89.2%)',
#   'Dose_2_Administered': '6,211,285 (72.8%)',
#   'Doses_Per_100_People': 216.12},
#  {'Location': 'Washington',
#   'Dose_1_Administered': '6,401,591 (84.1%)',
#   'Dose_2_Administered': '5,464,033 (71.8%)',
#   'Doses_Per_100_People': 217.84},
#  {'Location': 'West Virginia',
#   'Dose_1_Administered': '1,198,498 (66.9%)',
#   'Dose_2_Administered': '1,019,228 (56.9%)',
#   'Doses_Per_100_People': 166.96},
#  {'Location': 'Wisconsin',
#   'Dose_1_Administered': '4,317,892 (74.2%)',
#   'Dose_2_Administered': '3,782,610 (65.0%)',
#   'Doses_Per_100_People': 201.0},
#  {'Location': 'Wyoming',
#   'Dose_1_Administered': '348,109 (60.1%)',
#   'Dose_2_Administered': '284,573 (49.2%)',
#   'Doses_Per_100_People': 142.0}]

# %%
db.Dose.insert_many(data1)
